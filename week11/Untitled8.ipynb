# %%
import pandas as pd
import json
import urllib
from pandas import json_normalize

key = 'gUYGeK8GdkjaOY4AOL4uqL9z2d2pgLsh'
url = 'https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?'
string = url+'api-key='+key
string
# Out:
# 'https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=gUYGeK8GdkjaOY4AOL4uqL9z2d2pgLsh'

# %%
response = str(urllib.request.urlopen(string).read(), 'utf-8')

popular = pd.read_json(response)
popular
# Out:
#    status                                          copyright  num_results  \
# 0      OK  Copyright (c) 2021 The New York Times Company....           20
# 1      OK  Copyright (c) 2021 The New York Times Company....           20
# 2      OK  Copyright (c) 2021 The New York Times Company....           20
# 3      OK  Copyright (c) 2021 The New York Times Company....           20
# 4      OK  Copyright (c) 2021 The New York Times Company....           20
# 5      OK  Copyright (c) 2021 The New York Times Company....           20
# 6      OK  Copyright (c) 2021 The New York Times Company....           20
# 7      OK  Copyright (c) 2021 The New York Times Company....           20
# 8      OK  Copyright (c) 2021 The New York Times Company....           20
# 9      OK  Copyright (c) 2021 The New York Times Company....           20
# 10     OK  Copyright (c) 2021 The New York Times Company....           20
# 11     OK  Copyright (c) 2021 The New York Times Company....           20
# ...

# %%
data = json.loads(response)
mostpopular = json_normalize(data['results'])
mostpopular
# Out:
#                                                   uri  \
# 0   nyt://article/6fcd3192-a2a6-5f41-90ea-bdfb76f6...
# 1   nyt://article/116ae3a6-0df6-51ce-aa69-818116de...
# 2   nyt://article/e7fcda01-4edc-5784-8e5c-27d9cd42...
# 3   nyt://article/aded3ea5-492b-5be9-b316-6a898108...
# 4   nyt://article/e11eb782-2eca-5b57-a253-1a961d97...
# 5   nyt://article/371bec49-e869-5dba-bfd9-f40a29f3...
# 6   nyt://article/119864d2-55db-564d-b19a-0bf9ef86...
# 7   nyt://article/8896672a-510b-5ef9-a5b7-9350492a...
# 8   nyt://article/956b07ab-6783-5483-94a3-b7c001ad...
# 9   nyt://article/102370ef-1091-5e89-ae3c-efa401eb...
# 10  nyt://article/49b052e4-c740-564d-8c77-5eda953c...
# 11  nyt://article/4fe09854-04f8-50a0-96bf-da864a52...
# 12  nyt://article/dbb41e27-fd14-5c94-affa-97a5cde0...
# 13  nyt://article/f7f180ed-d250-59e2-930b-a37c3363...
# 14  nyt://article/ad10f8a9-2963-5791-8bc8-d2ddaa5f...
# 15  nyt://article/75a194f1-f0c7-5eb0-b7a8-6be90231...
# ...
