# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
unemployment = pd.read_csv('Unemployment Data.csv', index_col =0)
unemployment.head()
# Out:
#         Advanced Economies  Argentina  Australia   Austria   Belgium  \
# NaN                    NaN        NaN        NaN       NaN       NaN
# 1990.0            5.800582        NaN   6.943297  5.373002  6.550260
# 1991.0            6.728688        NaN   9.614137  5.823096  6.439812
# 1992.0            7.511064        NaN  10.750080  5.941711  7.088092
# 1993.0            7.936175        NaN  10.866170  6.811381  8.619130
#
#         Bulgaria  Bahrain  Belarus  Brazil    Canada  ...  Thailand  Tunisia  \
# NaN          NaN      NaN      NaN     NaN       NaN  ...       NaN      NaN
# 1990.0       NaN      NaN      NaN     NaN   8.15000  ...       NaN      NaN
# 1991.0       NaN      NaN      NaN     NaN  10.31667  ...       NaN      NaN
# 1992.0  13.23500      NaN      NaN     NaN  11.21667  ...       NaN      NaN
# 1993.0  15.85583      NaN      NaN     NaN  11.37500  ...       NaN      NaN
#
#         Turkey  Taiwan, China  Uruguay  United States  Venezuela, RB  Vietnam  \
# ...

# %%
unemployment.shape
# Out:
# (31, 84)

# %% [markdown]
# the dataframe is too wide, I decided to go long instead of wide.
# I use transpose function

# %%
T_unemployment = unemployment.T
T_unemployment.head()
# Out:
#                     NaN       1990.0    1991.0     1992.0     1993.0  \
# Advanced Economies     NaN  5.800582  6.728688   7.511064   7.936175
# Argentina              NaN       NaN       NaN        NaN        NaN
# Australia              NaN  6.943297  9.614137  10.750080  10.866170
# Austria                NaN  5.373002  5.823096   5.941711   6.811381
# Belgium                NaN  6.550260  6.439812   7.088092   8.619130
#
#                       1994.0    1995.0    1996.0    1997.0    1998.0  ...  \
# Advanced Economies  7.715897  7.264255  7.233725  6.942783  6.575284  ...
# Argentina                NaN       NaN       NaN       NaN       NaN  ...
# Australia           9.705695  8.471058  8.516425  8.363718  7.651377  ...
# Austria             6.545480  6.589767  7.033851  7.103283  7.184796  ...
# Belgium             9.753554  9.674164  9.544254  9.213055  9.338434  ...
#
#                       2010.0    2011.0    2012.0    2013.0    2014.0  \
# ...

# %%
T_unemployment.shape
# Out:
# (84, 31)

# %% [markdown]
# The dataframe has been tranposed, but the first column is NaN,
# I decided to check the NaN across the dataframe and clean their as necessary.

# %%
T_unemployment.isna().sum()
# Out:
# NaN       84
# 1990.0    60
# 1991.0    56
# 1992.0    53
# 1993.0    49
# 1994.0    48
# 1995.0    45
# 1996.0    45
# 1997.0    44
# 1998.0    44
# 1999.0    40
# 2000.0    36
# 2001.0    30
# 2002.0    26
# 2003.0    23
# 2004.0    19
# 2005.0    16
# 2006.0    11
# 2007.0    10
# 2008.0     7
# 2009.0     7
# 2010.0     6
# 2011.0     6
# 2012.0     4
# 2013.0     3
# 2014.0     2
# 2015.0     1
# 2016.0     4
# 2017.0     5
# 2018.0     6
# 2019.0    60
# dtype: int64

# %% [markdown]
# only one column is NaN, with none values.
# also notice that all column names (year) have been changed to float type.

# %%
T_unemployment=T_unemployment.dropna(axis=1, how='all')
T_unemployment.columns = T_unemployment.columns.astype(int)
T_unemployment
# Out:
#                          1990      1991       1992       1993      1994  \
# Advanced Economies   5.800582  6.728688   7.511064   7.936175  7.715897
# Argentina                 NaN       NaN        NaN        NaN       NaN
# Australia            6.943297  9.614137  10.750080  10.866170  9.705695
# Austria              5.373002  5.823096   5.941711   6.811381  6.545480
# Belgium              6.550260  6.439812   7.088092   8.619130  9.753554
# ...                       ...       ...        ...        ...       ...
# United States        5.616667  6.850000   7.491667   6.908333  6.100000
# Venezuela, RB             NaN       NaN        NaN        NaN       NaN
# Vietnam                   NaN       NaN        NaN        NaN       NaN
# World (WBG members)       NaN       NaN        NaN        NaN       NaN
# South Africa              NaN       NaN        NaN        NaN       NaN
#
#                          1995      1996      1997      1998       1999  ...  \
# ...

# %% [markdown]
# I am interested in the unempolyment information during the 2008 economic crisis. I would recall 2007 to 2011 data to compare.

# %%
Unemploy = T_unemployment.iloc[:, 17:22]
Unemploy
# Out:
#                           2007       2008       2009       2010       2011
# Advanced Economies    5.438309   5.849630   8.100637   8.394859   8.101695
# Argentina             8.445649   7.856905   8.667655   7.745787   7.153890
# Australia             4.369393   4.245417   5.564423   5.182639   5.084689
# Austria               6.212384   5.900163   7.277321   6.924775   6.724852
# Belgium               7.489034   6.964811   7.885441   8.309995   7.158032
# ...                        ...        ...        ...        ...        ...
# United States         4.616667   5.800000   9.283333   9.608333   8.933333
# Venezuela, RB         8.454433   7.341128   7.897162   8.514539   8.186364
# Vietnam                    NaN   2.380000   2.900000   2.880000   2.220000
# World (WBG members)   5.948983   6.760382   7.590846   7.381281   7.201790
# South Africa         22.884760  22.467650  23.667370  24.840640  24.788550
#
# [84 rows x 5 columns]

# %% [markdown]
# Notice there are some NaN value in this frame, I would exclude all rows with NaN.

# %%
Unemploy=Unemploy.dropna()
Unemploy.isnull().sum()
# Out:
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# dtype: int64

# %%
Unemploy
# Out:
#                           2007       2008       2009       2010       2011
# Advanced Economies    5.438309   5.849630   8.100637   8.394859   8.101695
# Argentina             8.445649   7.856905   8.667655   7.745787   7.153890
# Australia             4.369393   4.245417   5.564423   5.182639   5.084689
# Austria               6.212384   5.900163   7.277321   6.924775   6.724852
# Belgium               7.489034   6.964811   7.885441   8.309995   7.158032
# ...                        ...        ...        ...        ...        ...
# Uruguay               9.400000   7.925000   7.783333   7.025000   6.341667
# United States         4.616667   5.800000   9.283333   9.608333   8.933333
# Venezuela, RB         8.454433   7.341128   7.897162   8.514539   8.186364
# World (WBG members)   5.948983   6.760382   7.590846   7.381281   7.201790
# South Africa         22.884760  22.467650  23.667370  24.840640  24.788550
#
# [74 rows x 5 columns]

# %% [markdown]
# This dataframe calcuates mean, std, min, 25%, 50%, 75% and max value for every years.

# %%
Unemploy.describe()
# Out:
#             2007       2008       2009       2010       2011
# count  74.000000  74.000000  74.000000  74.000000  74.000000
# mean    7.171584   6.999021   8.543499   8.898280   8.685206
# std     5.053857   4.852484   4.831004   5.256434   5.377487
# min     1.057151   0.930972   0.892368   0.815331   0.650000
# 25%     4.329848   4.073592   5.638542   5.872574   5.804599
# 50%     6.042744   6.215661   7.774841   7.796995   7.350895
# 75%     8.356312   7.736170   9.442823  10.000000  10.340133
# max    34.927550  33.775520  32.173120  32.044740  31.371430

# %% [markdown]
# Compare the mean values, we can see the unemployment rate reach to the highest in 2010.

# %%
Unemploy.describe().iloc[1].plot(kind = 'bar')

# %% [markdown]
# Top 5 countries/regions with the highest unemployment rate. compare by average of 5 years data.

# %%
mean = Unemploy.agg("mean", axis="columns")
mean.sort_values(ascending=False).head()
# Out:
# North Macedonia            32.858472
# South Africa               23.729794
# EMDE Sub-Saharan Africa    23.729794
# Spain                      15.735000
# Croatia                    15.376668
# dtype: float64

# %% [markdown]
# show in 2010, top 5 lowest unemployment countries.

# %%
Unemploy.sort_values(by=[2010]).head()
# Out:
#                  2007      2008      2009      2010      2011
# Belarus      1.057151  0.930972  0.892368  0.815331  0.666617
# Thailand     1.347500  1.355833  1.479167  1.035833  0.650000
# Singapore    2.100000  2.275000  3.000000  2.175000  2.025000
# Switzerland  2.761492  2.573748  3.712955  3.515214  2.836462
# Bahrain      5.600000  3.700000  4.000000  3.600000  4.000000
